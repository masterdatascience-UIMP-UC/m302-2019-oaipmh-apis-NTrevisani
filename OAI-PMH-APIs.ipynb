# %% [markdown]
# # OAI-PMH
#
# La documentación del protocolo la podéis encontrar aquí:
#
# https://www.openarchives.org/OAI/openarchivesprotocol.html
#
# ### Librerías necesarias para la práctica
#
# ```python
# import xml.etree.ElementTree as ET
# import requests
# import json
# ```

# %%
import xml.etree.ElementTree as ET
import requests
import json

# %% [markdown]
# ### Identify
#
# This verb is used to retrieve information about a repository. Some of the information returned is required as part of the OAI-PMH. Repositories may also employ the Identify verb to return additional descriptive information.

# %%
import xml.etree.ElementTree as ET
import requests

# https://zenodo.org/oai2d + el verbo que quiero utiilzar

oai = requests.get('https://zenodo.org/oai2d?verb=Identify') #Peticion al servidor

#Para crear el arbol XML
xmlTree = ET.fromstring(oai.text)
print(oai.text)
print()
# Out:
# <?xml version='1.0' encoding='UTF-8'?>
# <?xml-stylesheet type="text/xsl" href="/static/xsl/oai2.xsl"?>
# <OAI-PMH xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/ http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd">
#   <responseDate>2019-12-27T22:24:12Z</responseDate>
#   <request verb="Identify">https://zenodo.org/oai2d</request>
#   <Identify>
#     <repositoryName>Zenodo</repositoryName>
#     <baseURL>https://zenodo.org/oai2d</baseURL>
#     <protocolVersion>2.0</protocolVersion>
#     <adminEmail>info@zenodo.org</adminEmail>
#     <earliestDatestamp>2014-02-03T14:41:33Z</earliestDatestamp>
#     <deletedRecord>no</deletedRecord>
#     <granularity>YYYY-MM-DDThh:mm:ssZ</granularity>
#   </Identify>
# </OAI-PMH>

# %%
#Iterator para recorrer todos los elementos (incluso anidados)
iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag+": "+elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH:
#
# {http://www.openarchives.org/OAI/2.0/}responseDate: 2019-12-27T22:24:12Z
# {http://www.openarchives.org/OAI/2.0/}request: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}Identify:
#
# {http://www.openarchives.org/OAI/2.0/}repositoryName: Zenodo
# {http://www.openarchives.org/OAI/2.0/}baseURL: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}protocolVersion: 2.0
# {http://www.openarchives.org/OAI/2.0/}adminEmail: info@zenodo.org
# {http://www.openarchives.org/OAI/2.0/}earliestDatestamp: 2014-02-03T14:41:33Z
# {http://www.openarchives.org/OAI/2.0/}deletedRecord: no
# {http://www.openarchives.org/OAI/2.0/}granularity: YYYY-MM-DDThh:mm:ssZ

# %%
#Findall para encontrar un elemento específico (en este caso, el baseURL)
namespaces = {'ns': 'http://www.openarchives.org/OAI/2.0/'} # add more as needed
elementos = xmlTree.findall('.//ns:baseURL',namespaces) # aquí digo lo que estoy buscando y en qué formato de metadatos
# Imprimo el elemento que quiero en formato poco legible
print(elementos) #Element

# Imprimo en formato legible
for e in elementos:
    print("BaseURL:", e.text)
# Out:
# [<Element '{http://www.openarchives.org/OAI/2.0/}baseURL' at 0x7f713cd9e470>]
# BaseURL: https://zenodo.org/oai2d

# %% [markdown]
# ### Listar tipos de metadatos
#
# ListMetadataFormats
#
# This verb is used to retrieve the metadata formats available from a repository. An optional argument restricts the request to the formats available for a specific item.

# %%
# Aquí hago lo mismo que antes:
# 1) hago una petición al servidor usando request.get() -- ahora uso el verbo ListMetadataFormats
# 2) creo que el arbol xml con ET.fromstring(oai.text)
# 3) pinto el arbol xml de manera legible, usando el iterador xmlTree.iter()

import xml.etree.ElementTree as ET
import requests

oai = requests.get('https://zenodo.org/oai2d?verb=ListMetadataFormats') #Peticion al servidor

#Para crear el arbol XML
xmlTree = ET.fromstring(oai.text)

iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag+": "+elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH:
#
# {http://www.openarchives.org/OAI/2.0/}responseDate: 2019-12-27T22:24:14Z
# {http://www.openarchives.org/OAI/2.0/}request: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListMetadataFormats:
#
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marcxml
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://www.loc.gov/MARC21/slim
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite4
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-4
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_dc
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.openarchives.org/OAI/2.0/oai_dc.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://www.openarchives.org/OAI/2.0/oai_dc/
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: dcat
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: https://www.w3.org/ns/dcat
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-3
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marc21
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://www.loc.gov/MARC21/slim
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-4
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-3
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite4
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-4
# {http://www.openarchives.org/OAI/2.0/}metadataFormat:
#
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataNamespace: http://datacite.org/schema/kernel-3

# %% [markdown]
# Podemos capturar sólo la información relevante

# %%
# aquí decido imprimir solo las informaciones que quiero:
# metadataPrefix y schema
iterator = xmlTree.iter()
for elem in iterator:
    if (elem.tag == '{http://www.openarchives.org/OAI/2.0/}metadataPrefix') or (elem.tag == '{http://www.openarchives.org/OAI/2.0/}schema'):
        print(elem.tag+": "+elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marcxml
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite4
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_dc
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.openarchives.org/OAI/2.0/oai_dc.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: dcat
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: marc21
# {http://www.openarchives.org/OAI/2.0/}schema: http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: datacite4
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# {http://www.openarchives.org/OAI/2.0/}metadataPrefix: oai_datacite3
# {http://www.openarchives.org/OAI/2.0/}schema: http://schema.datacite.org/meta/kernel-3/metadata.xsd

# %% [markdown]
# O de forma más "elegante"

# %%
# Todavia mejor
for e in xmlTree.findall('.//{http://www.openarchives.org/OAI/2.0/}metadataFormat'):
    metadataPrefix = e.find('{http://www.openarchives.org/OAI/2.0/}metadataPrefix').text
    schema = e.find('{http://www.openarchives.org/OAI/2.0/}schema').text
    print(metadataPrefix, ':', schema)
# Out:
# marcxml : http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# oai_datacite4 : http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# oai_dc : http://www.openarchives.org/OAI/2.0/oai_dc.xsd
# dcat : http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# oai_datacite : http://schema.datacite.org/meta/kernel-3/metadata.xsd
# marc21 : http://www.loc.gov/standards/marcxml/schema/MARC21slim.xsd
# datacite : http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# datacite3 : http://schema.datacite.org/meta/kernel-3/metadata.xsd
# datacite4 : http://schema.datacite.org/meta/kernel-4.1/metadata.xsd
# oai_datacite3 : http://schema.datacite.org/meta/kernel-3/metadata.xsd

# %% [markdown]
# Podemos describir el último schema

# %%
# Cojo el ultimo 'schema' y hago una petición al servidor 
oai_datacite = requests.get('http://schema.datacite.org/meta/kernel-3/metadata.xsd') #Peticion al servidor
# Imprimo (no se entiende nada)
print(oai_datacite.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <!-- Revision history
#      2010-08-26   Complete revision according to new common specification by the metadata work group after review. AJH, DTIC
# 	 2010-11-17 Revised to current state of kernel review, FZ, TIB
# 	 2011-01-17 Complete revsion after community review. FZ, TIB
# 	 2011-03-17 Release of v2.1: added a namespace; mandatory properties got minLength; changes in the definitions of relationTypes
# 	 IsDocumentedBy/Documents and isCompiledBy/Compiles; changes type of property "Date" from xs:date to xs:string. FZ, TIB
# 	 2011-06-27 v2.2: namespace: kernel-2.2, additions to controlled lists "resourceType", "contributorType", "relatedIdentifierType", and "descriptionType". Removal of intermediate include-files.
#      2013-05 v3.0: namespace: kernel-3.0; delete LastMetadataUpdate & MetadateVersionNumber; additions to controlled lists "contributorType", "dateType", "descriptionType", "relationType", "relatedIdentifierType" & "resourceType"; deletion of "StartDate" & "EndDate" from list "dateType" and "Film" from "resourceType";  allow arbitrary order of elements; allow optional wrapper elements to be empty; include xml:lang attribute for title, subject & description; include attribute schemeURI for nameIdentifier of creator, contributor & subject; added new attributes "relatedMetadataScheme", "schemeURI" & "schemeType" to relatedIdentifier; included new property "geoLocation"
# 	 2014-08-20 v3.1: additions to controlled lists "relationType", contributorType" and "relatedIdentifierType"; introduction of new child element "affiliation" to "creator" and "contributor"-->
# <xs:schema xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns="http://datacite.org/schema/kernel-3" targetNamespace="http://datacite.org/schema/kernel-3" elementFormDefault="qualified" xml:lang="EN">
# 	<xs:import namespace="http://www.w3.org/XML/1998/namespace" schemaLocation="http://www.w3.org/2009/01/xml.xsd"/>
# 	<xs:include schemaLocation="include/datacite-titleType-v3.xsd"/>
# 	<xs:include schemaLocation="include/datacite-contributorType-v3.1.xsd"/>
# 	<xs:include schemaLocation="include/datacite-dateType-v3.xsd"/>
# 	<xs:include schemaLocation="include/datacite-resourceType-v3.xsd"/>
# 	<xs:include schemaLocation="include/datacite-relationType-v3.1.xsd"/>
# 	<xs:include schemaLocation="include/datacite-relatedIdentifierType-v3.1.xsd"/>
# 	<xs:include schemaLocation="include/datacite-descriptionType-v3.xsd"/>
# 	<xs:element name="resource">
# 		<xs:annotation>
# 			<xs:documentation>
# 	Root element of a single record. This wrapper element is for XML implementation only and is not defined in the DataCite DOI standard.
#         Note: This is the case for all wrapper elements within this schema!</xs:documentation>
# 			<xs:documentation>No content in this wrapper element.</xs:documentation>
# 		</xs:annotation>
# 		<xs:complexType>
# 			<xs:all>
# 				<!--REQUIRED FIELDS-->
# 				<xs:element name="identifier">
# 					<xs:annotation>
# 						<xs:documentation>A persistent identifier that identifies a resource.</xs:documentation>
# 						<xs:documentation>Currently, only DOI is allowed.</xs:documentation>
# 					</xs:annotation>
# 					<xs:complexType>
# 						<xs:simpleContent>
# 							<xs:extension base="doiType">
# 								<xs:attribute name="identifierType" use="required" fixed="DOI"/>
# 							</xs:extension>
# 						</xs:simpleContent>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="creators">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="creator" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>The main researchers involved working on the data, or the authors of the publication in priority order. May be a corporate/institutional or personal name.</xs:documentation>
# 									<xs:documentation>Format: Family, Given.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:sequence>
# 										<xs:element name="creatorName">
# 											<xs:simpleType>
# 												<xs:restriction base="nonemptycontentStringType"/>
# 											</xs:simpleType>
# 										</xs:element>
# 										<xs:element name="nameIdentifier" minOccurs="0">
# 											<xs:complexType>
# 												<xs:simpleContent>
# 													<xs:extension base="nonemptycontentStringType">
# 														<xs:attribute name="nameIdentifierScheme" use="required"/>
# 														<xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
# 													</xs:extension>
# 												</xs:simpleContent>
# 											</xs:complexType>
# 										</xs:element>
# 										<xs:element name="affiliation" minOccurs="0" maxOccurs="unbounded"/>
# 									</xs:sequence>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="titles">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="title" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>A name or title by which a resource is known.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="nonemptycontentStringType">
# 											<xs:attribute name="titleType" type="titleType" use="optional"/>
# 											<xs:attribute ref="xml:lang"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="publisher">
# 					<xs:annotation>
# 						<xs:documentation>The name of the entity that holds, archives, publishes prints, distributes, releases, issues, or produces the resource. This property will be used to formulate the citation, so consider the prominence of the role.</xs:documentation>
# 						<xs:documentation>In the case of datasets, "publish" is understood to mean making the data available to the community of researchers.</xs:documentation>
# 					</xs:annotation>
# 					<xs:simpleType>
# 						<xs:restriction base="nonemptycontentStringType"/>
# 					</xs:simpleType>
# 				</xs:element>
# 				<xs:element name="publicationYear">
# 					<xs:annotation>
# 						<xs:documentation>Year when the data is made publicly available. If an embargo period has been in effect, use the date when the embargo period ends.</xs:documentation>
# 						<xs:documentation>In the case of datasets, "publish" is understood to mean making the data available on a specific date to the community of researchers. If there is no standard publication year value, use the date that would be preferred from a citation perspective.</xs:documentation>
# 						<xs:documentation>YYYY</xs:documentation>
# 					</xs:annotation>
# 					<xs:simpleType>
# 						<xs:restriction base="yearType"/>
# 					</xs:simpleType>
# 				</xs:element>
# 				<!--OPTIONAL FIELDS-->
# 				<xs:element name="subjects" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="subject" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Subject, keywords, classification codes, or key phrases describing the resource.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="xs:string">
# 											<xs:attribute name="subjectScheme" use="optional"/>
# 											<xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
# 											<xs:attribute ref="xml:lang"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="contributors" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="contributor" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>The institution or person responsible for collecting, creating, or otherwise contributing to the developement of the dataset.</xs:documentation>
# 									<xs:documentation>The personal name format should be: Family, Given.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:sequence>
# 										<xs:element name="contributorName">
# 											<xs:simpleType>
# 												<xs:restriction base="xs:string">
# 													<xs:minLength value="1"/>
# 												</xs:restriction>
# 											</xs:simpleType>
# 										</xs:element>
# 										<xs:element name="nameIdentifier" minOccurs="0">
# 											<xs:complexType>
# 												<xs:simpleContent>
# 													<xs:extension base="xs:string">
# 														<xs:attribute name="nameIdentifierScheme" use="required"/>
# 														<xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
# 													</xs:extension>
# 												</xs:simpleContent>
# 											</xs:complexType>
# 										</xs:element>
# 										<xs:element name="affiliation" minOccurs="0" maxOccurs="unbounded"/>
# 									</xs:sequence>
# 									<xs:attribute name="contributorType" type="contributorType" use="required"/>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="dates" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="date" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Different dates relevant to the work.</xs:documentation>
# 									<xs:documentation>YYYY,YYYY-MM-DD, YYYY-MM-DDThh:mm:ssTZD or any other format or level of granularity described in W3CDTF. Use RKMS-ISO8601 standard for depicting date ranges.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="xs:string">
# 											<xs:attribute name="dateType" type="dateType" use="required"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="language" type="xs:language" minOccurs="0">
# 					<xs:annotation>
# 						<xs:documentation>Primary language of the resource. Allowed values are taken from  IETF BCP 47, ISO 639-1 language codes.</xs:documentation>
# 					</xs:annotation>
# 				</xs:element>
# 				<xs:element name="resourceType" minOccurs="0">
# 					<xs:annotation>
# 						<xs:documentation>The type of a resource. You may enter an additional free text description.</xs:documentation>
# 						<xs:documentation>The format is open, but the preferred format is a single term of some detail so that a pair can be formed with the sub-property.</xs:documentation>
# 					</xs:annotation>
# 					<xs:complexType>
# 						<xs:simpleContent>
# 							<xs:extension base="xs:string">
# 								<xs:attribute name="resourceTypeGeneral" type="resourceType" use="required"/>
# 							</xs:extension>
# 						</xs:simpleContent>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="alternateIdentifiers" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="alternateIdentifier" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>An identifier or identifiers other than the primary Identifier applied to the resource being registered. This may be any alphanumeric string which is unique within its domain of issue. May be used for local identifiers. AlternateIdentifier should be used for another identifier of the same instance (same location, same file).</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="xs:string">
# 											<xs:attribute name="alternateIdentifierType" use="required"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="relatedIdentifiers" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="relatedIdentifier" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Identifiers of related resources. Use this property to indicate subsets of properties, as appropriate.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="xs:string">
# 											<xs:attribute name="relatedIdentifierType" type="relatedIdentifierType" use="required"/>
# 											<xs:attribute name="relationType" type="relationType" use="required"/>
# 											<xs:attribute name="relatedMetadataScheme" use="optional"/>
# 											<xs:attribute name="schemeURI" type="xs:anyURI" use="optional"/>
# 											<xs:attribute name="schemeType" use="optional"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="sizes" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="size" type="xs:string" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Unstructures size information about the resource.</xs:documentation>
# 								</xs:annotation>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="formats" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="format" type="xs:string" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Technical format of the resource.</xs:documentation>
# 									<xs:documentation>Use file extension or MIME type where possible.</xs:documentation>
# 								</xs:annotation>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="version" type="xs:string" minOccurs="0">
# 					<xs:annotation>
# 						<xs:documentation>Version number of the resource. If the primary resource has changed the version number increases.</xs:documentation>
# 						<xs:documentation>Register a new identifier for a major version change. Individual stewards need to determine which are major vs. minor versions. May be used in conjunction with properties 11 and 12 (AlternateIdentifier and RelatedIdentifier) to indicate various information updates. May be used in conjunction with property 17 (Description) to indicate the nature and file/record range of version.</xs:documentation>
# 					</xs:annotation>
# 				</xs:element>
# 				<xs:element name="rightsList" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="rights" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Any rights information for this resource. Provide a rights management statement for the resource or reference a service providing such information. Include embargo information if applicable.
# Use the complete title of a license and include version information if applicable.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:simpleContent>
# 										<xs:extension base="xs:string">
# 											<xs:attribute name="rightsURI" type="xs:anyURI" use="optional"/>
# 										</xs:extension>
# 									</xs:simpleContent>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="descriptions" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="description" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>All additional information that does not fit in any of the other categories. May be used for technical information. It is a best practice to supply a description.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType mixed="true">
# 									<xs:choice>
# 										<xs:element name="br" minOccurs="0" maxOccurs="unbounded">
# 											<xs:simpleType>
# 												<xs:restriction base="xs:string">
# 													<xs:length value="0"/>
# 												</xs:restriction>
# 											</xs:simpleType>
# 										</xs:element>
# 									</xs:choice>
# 									<xs:attribute name="descriptionType" type="descriptionType" use="required"/>
# 									<xs:attribute ref="xml:lang"/>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 				<xs:element name="geoLocations" minOccurs="0">
# 					<xs:complexType>
# 						<xs:sequence>
# 							<xs:element name="geoLocation" minOccurs="0" maxOccurs="unbounded">
# 								<xs:annotation>
# 									<xs:documentation>Spatial region or named place where the data was gathered or about which the data is focused.</xs:documentation>
# 									<xs:documentation>A point contains a single latitude-longitude pair, separated by whitespace.</xs:documentation>
# 									<xs:documentation>A box contains two white space separated latitude-longitude pairs, with each pair separated by whitespace. The first pair is the lower corner, the second is the upper corner.</xs:documentation>
# 								</xs:annotation>
# 								<xs:complexType>
# 									<xs:sequence>
# 										<xs:element name="geoLocationPoint" type="point" minOccurs="0"/>
# 										<xs:element name="geoLocationBox" type="box" minOccurs="0"/>
# 										<xs:element name="geoLocationPlace" minOccurs="0"/>
# 									</xs:sequence>
# 								</xs:complexType>
# 							</xs:element>
# 						</xs:sequence>
# 					</xs:complexType>
# 				</xs:element>
# 			</xs:all>
# 		</xs:complexType>
# 	</xs:element>
# 	<!-- TYPE DECLARATIONS -->
# 	<!-- defines the value for a DOI: DOI must start with "10."  -->
# 	<xs:simpleType name="doiType">
# 		<xs:restriction base="xs:token">
# 			<xs:pattern value="10\..+/.+"/>
# 		</xs:restriction>
# 	</xs:simpleType>
# 	<!-- defines value for mandatory fields -->
# 	<xs:simpleType name="nonemptycontentStringType">
# 		<xs:restriction base="xs:string">
# 			<xs:minLength value="1"/>
# 		</xs:restriction>
# 	</xs:simpleType>
# 	<xs:attributeGroup name="nameId">
# 		<xs:attribute name="nameIdentifier" type="xs:string" use="optional"/>
# 		<xs:attribute name="nameIdentifierScheme" type="xs:string" use="optional"/>
# 	</xs:attributeGroup>
# 	<!-- defines the value for a year -->
# 	<xs:simpleType name="yearType">
# 		<xs:restriction base="xs:token">
# 			<xs:pattern value="[\d]{4}"/>
# 		</xs:restriction>
# 		<!-- definitions for geoLocation -->
# 	</xs:simpleType>
# 	<xs:simpleType name="point">
# 		<xs:restriction base="listOfDoubles">
# 			<xs:minLength value="2"/>
# 			<xs:maxLength value="2"/>
# 		</xs:restriction>
# 	</xs:simpleType>
# 	<xs:simpleType name="box">
# 		<xs:restriction base="listOfDoubles">
# 			<xs:minLength value="4"/>
# 			<xs:maxLength value="4"/>
# 		</xs:restriction>
# 	</xs:simpleType>
# 	<xs:simpleType name="listOfDoubles">
# 		<xs:list itemType="xs:double"/>
# 	</xs:simpleType>
# </xs:schema>

# %%
#Para crear el arbol XML
xmlTree = ET.fromstring(oai_datacite.text)

# Lo imprimo (ya algo se lee)
iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag)
# Out:
# {http://www.w3.org/2001/XMLSchema}schema
# {http://www.w3.org/2001/XMLSchema}import
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}include
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}all
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}minLength
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}simpleContent
# {http://www.w3.org/2001/XMLSchema}extension
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}choice
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}length
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}annotation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}documentation
# {http://www.w3.org/2001/XMLSchema}complexType
# {http://www.w3.org/2001/XMLSchema}sequence
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}element
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}pattern
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}minLength
# {http://www.w3.org/2001/XMLSchema}attributeGroup
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}attribute
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}pattern
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}minLength
# {http://www.w3.org/2001/XMLSchema}maxLength
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}restriction
# {http://www.w3.org/2001/XMLSchema}minLength
# {http://www.w3.org/2001/XMLSchema}maxLength
# {http://www.w3.org/2001/XMLSchema}simpleType
# {http://www.w3.org/2001/XMLSchema}list

# %% [markdown]
# Si analizamos la descripción del estándar, vemos que las etiquetas de los metadatos están almacenados en la etiqueta "element", en el atributo "name". Podemos obetener un listado de lo que esperamos encontrar

# %%
namespaces = {'xs' : 'http://www.w3.org/2001/XMLSchema'}
for tags in xmlTree.findall('.//xs:element',namespaces):
    print ('Metadato: ',tags.attrib['name'])
# Out:
# Metadato:  resource
# Metadato:  identifier
# Metadato:  creators
# Metadato:  creator
# Metadato:  creatorName
# Metadato:  nameIdentifier
# Metadato:  affiliation
# Metadato:  titles
# Metadato:  title
# Metadato:  publisher
# Metadato:  publicationYear
# Metadato:  subjects
# Metadato:  subject
# Metadato:  contributors
# Metadato:  contributor
# Metadato:  contributorName
# Metadato:  nameIdentifier
# Metadato:  affiliation
# Metadato:  dates
# Metadato:  date
# Metadato:  language
# Metadato:  resourceType
# Metadato:  alternateIdentifiers
# Metadato:  alternateIdentifier
# Metadato:  relatedIdentifiers
# Metadato:  relatedIdentifier
# Metadato:  sizes
# Metadato:  size
# Metadato:  formats
# Metadato:  format
# Metadato:  version
# Metadato:  rightsList
# Metadato:  rights
# Metadato:  descriptions
# Metadato:  description
# Metadato:  br
# Metadato:  geoLocations
# Metadato:  geoLocation
# Metadato:  geoLocationPoint
# Metadato:  geoLocationBox
# Metadato:  geoLocationPlace

# %% [markdown]
# ### ListIdentifiers
#
# This verb is an abbreviated form of ListRecords, retrieving only headers rather than records. Optional arguments permit selective harvesting of headers based on set membership and/or datestamp. Depending on the repository's support for deletions, a returned header may have a status attribute of "deleted" if a record matching the arguments specified in the request has been deleted.
#
# Devuelve la cabecera de los registros, para conocer la información esencial.
#
# Necesita el prefijo del formato de metadatos

# %%
# pongo verbo y prefijo

# verbo: ListIdentifiers (verb=ListIdentifiers)
# prefijo: oai_datacite  (metadataPrefix=oai_datacite)

# empiezo con un '?'
# junto los dos con una '&'

oai = requests.get('https://zenodo.org/oai2d?verb=ListIdentifiers&metadataPrefix=oai_datacite')
xmlTree = ET.fromstring(oai.text)

iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag+": "+elem.text) #Identifiers are really important because they are used to ask more information
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH:
#
# {http://www.openarchives.org/OAI/2.0/}responseDate: 2019-12-27T22:24:18Z
# {http://www.openarchives.org/OAI/2.0/}request: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListIdentifiers:
#
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3234674
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:30Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3234141
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:30Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3229933
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:30Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3229408
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:30Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3228524
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:30Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3228104
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:31Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3228161
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:31Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:2617377
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:31Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:2613564
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:31Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:2605517
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:32Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:2605181
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:32Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:2600509
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:33Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:56551
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:35Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:56583
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:35Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:56124
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:56055
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:55838
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:11998
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}setSpec: user-zenodo
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:55556
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:55241
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:51325
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:37Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:54919
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:37Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:53201
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:37Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:53111
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:37Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:51811
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:37Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:51558
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:38Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:51614
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:38Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:51513
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:38Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:51515
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:38Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:51267
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:38Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:50801
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:38Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:32765
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:38Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:50968
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:38Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:50720
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:38Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:50622
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:39Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:50427
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:39Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:50403
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:39Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:50184
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:39Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:50157
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:39Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:50100
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:39Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:50048
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:39Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:50033
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:39Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:49967
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-11-01T07:14:39Z
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:49298
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019
#
# This verb is used to harvest records from a repository. Optional arguments permit selective harvesting of records based on set membership and/or datestamp. Depending on the repository's support for deletions, a returned header may have a status attribute of "deleted" if a record matching the arguments specified in the request has been deleted. No metadata will be present for records with deleted status.

# %%
import xml.etree.ElementTree as ET
import requests

oai = requests.get('https://zenodo.org/oai2d?verb=ListRecords&metadataPrefix=oai_datacite')
xmlTree = ET.fromstring(oai.text)
iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag)
    print(elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH
#
#
# {http://www.openarchives.org/OAI/2.0/}responseDate
# 2019-12-27T22:24:19Z
# {http://www.openarchives.org/OAI/2.0/}request
# https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListRecords
#
#
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3234674
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:30Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.3234674
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Falko Hegerfeld
# {http://datacite.org/schema/kernel-3}affiliation
# Humboldt-Universität zu Berlin
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Florian Nelles
# {http://datacite.org/schema/kernel-3}affiliation
# Humboldt-Universität zu Berlin
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# hubhegnel/pace-2019: Release for zenodo
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# vertex cover
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-05-29
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/hubhegnel/pace-2019/tree/z1.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.3234673
# {http://datacite.org/schema/kernel-3}version
# z1.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Submission for PACE 2019 Track 1a Vertex Cover Exact.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3234141
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:30Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.3234141
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Jorrit Poelen
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# beraute
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# beraute/Klamath-mountains: Klamath mountains eDNA interactions
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-05-28
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/beraute/Klamath-mountains/tree/v1.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.3234140
# {http://datacite.org/schema/kernel-3}version
# v1.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>A table of organism interactions found in eDNA samples collected in the Klamath mountains in the summer of 2018.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3229933
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:30Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.3229933
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Marissa Lee
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# marissalee/MetaInvN: publication metadata
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-05-27
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/marissalee/MetaInvN/tree/v1.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.3229932
# {http://datacite.org/schema/kernel-3}version
# v1.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# Invasive species' leaf traits and dissimilarity from natives shape their impact on nitrogen cycling: a meta-analysis
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3229408
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:30Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.3229408
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Etherington, T. R.
# {http://datacite.org/schema/kernel-3}nameIdentifier
# 0000-0002-3187-075X
# {http://datacite.org/schema/kernel-3}affiliation
# Manaaki Whenua - Landcare Research
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# [Re] Resampling methods for evaluating classification accuracy of wildlife habitat models
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-05-26
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.3229407
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# MIT License
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>ReScience C code to replicate the following article:</p>
#
# <p>Verbyla DL, Litvaitis JA (1989) Resampling methods for evaluating classification accuracy of wildlife habitat models. Environmental Management 13:783-787 <a href="https://doi.org/10.1007/BF01868317">https://doi.org/10.1007/BF01868317</a></p>
#
# <p>where the authors examined different resampling methods to test wildife habitat models.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3228524
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:30Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.3228524
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Jackson M. Tsuji
# {http://datacite.org/schema/kernel-3}affiliation
# @neufeld
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# jmtsuji/chlorobia-cyc2-genomics: First release
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-05-24
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/jmtsuji/chlorobia-cyc2-genomics/tree/v1.0.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.3228523
# {http://datacite.org/schema/kernel-3}version
# v1.0.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Project code is now available online.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3228104
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:31Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.3228104
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Thomas Koentges
# {http://datacite.org/schema/kernel-3}nameIdentifier
# 0000-0002-9425-5850
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Adrian Chitralla
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# ThomasK81/gocite: Phoenix
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-05-24
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/ThomasK81/gocite/tree/2.0.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1257466
# {http://datacite.org/schema/kernel-3}version
# 2.0.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Broke the API partially, restructured Work and Passage object. First and Last information is now in Works not in Passages. Improved SortPassages.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:3228161
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:31Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.3228161
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Hijma, Pieter
# {http://datacite.org/schema/kernel-3}affiliation
# Vrije Universiteit Amsterdam
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Common Source Identification Cashmere Native
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Java
# {http://datacite.org/schema/kernel-3}subject
# GPU
# {http://datacite.org/schema/kernel-3}subject
# OpenCL
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-05-24
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/JungleComputing/common-source-identification-cashmere-native/tree/v1.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1326429
# {http://datacite.org/schema/kernel-3}version
# v1.1.1
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Apache License 2.0
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# Common Source Identification Cashmere Native
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2617377
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:31Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.2617377
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# David Schmidt
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# schmidii/data_experiment: Data Stewardship Project
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-03-30
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/schmidii/data_experiment/tree/1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.2617376
# {http://datacite.org/schema/kernel-3}version
# 1
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>First Relesase of the Data Stewardship Project</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2613564
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:31Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.2613564
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Peter Harrison
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# pmcharrison/voicer-analysis: Initial release
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-03-28
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/pmcharrison/voicer-analysis/tree/v0.1.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.2613563
# {http://datacite.org/schema/kernel-3}version
# v0.1.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# Analyses for "A Computational Model for the Analysis and Generation of Chord Voicings"
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2605517
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:32Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.2605517
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Douglas Rosa
# {http://datacite.org/schema/kernel-3}affiliation
# Ética TI
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# douglasrosa0110/github-tests: First release
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-03-25
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/douglasrosa0110/github-tests/tree/v1.0.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.2605516
# {http://datacite.org/schema/kernel-3}version
# v1.0.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>The first release of the test app</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2605181
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:32Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.2605181
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Andrew McCluskey
# {http://datacite.org/schema/kernel-3}affiliation
# University of Bath/Diamond Light Source
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# arm61/fitoog: fitoog-0.1
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-03-25
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/arm61/fitoog/tree/0.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.2605180
# {http://datacite.org/schema/kernel-3}version
# 0.1
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# molecular SAS fitting with MPI
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:2600509
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:33Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.2600509
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Reed A. Cartwright
# {http://datacite.org/schema/kernel-3}affiliation
# Arizona State University
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# reedacartwright/toycoati v0.2
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2019
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2019-03-21
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/reedacartwright/toycoati/tree/v0.2
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.2596172
# {http://datacite.org/schema/kernel-3}version
# v0.2
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# An FST for generating pairwise alignments
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:56551
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:35Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.56551
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Warwick Wainwright
# {http://datacite.org/schema/kernel-3}affiliation
# University of Edinburgh
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# planets: Version 1
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-06-28
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/wainwrigh/planets/tree/1.0
# {http://datacite.org/schema/kernel-3}version
# 1.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Version 1 of document concerning Mars.  </p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:56583
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:35Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.56583
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# John Rugis
# {http://datacite.org/schema/kernel-3}affiliation
# University of Auckland
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Chris Scott
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# cellsim_34_vcl: The initial release.
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-06-29
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/jrugis/cellsim_34_vcl/tree/v1.0.0
# {http://datacite.org/schema/kernel-3}version
# v1.0.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# GNU General Public License v3.0 only
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>This release supports both linux (Ubuntu 14.04) and University of Auckland pan cluster builds.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:56124
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.56124
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Wenjie Lei
# {http://datacite.org/schema/kernel-3}affiliation
# Princeton University
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Xin Song
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Matthieu Lefebvre
# {http://datacite.org/schema/kernel-3}affiliation
# Princeton University
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# pycmt3d v1.0
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-06-21
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/wjlei1990/pycmt3d/tree/v1.0
# {http://datacite.org/schema/kernel-3}version
# v1.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Doc:</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:56055
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.56055
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Will Landau
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# fbseqComputation: Release for version 0.0
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-06-20
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/wlandau/fbseqComputation/tree/0.0
# {http://datacite.org/schema/kernel-3}version
# 0.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>This release accompanies the first submission of a JASA case study.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:55838
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.55838
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Justin B. Kinney
# {http://datacite.org/schema/kernel-3}affiliation
# Cold Spring Harbor Laboratory
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# irelandb
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# mpathic: First release, second attempt
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-06-17
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/jbkinney/mpathic/tree/v0.01.02
# {http://datacite.org/schema/kernel-3}version
# v0.01.02
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>First release of the MPAthic software package</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:11998
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-zenodo
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.11998
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Will Mayner
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# cyphi 0.1.0
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2014
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2014-10-08
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/wmayner/cyphi/tree/0.1.0
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/zenodo
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>A Python library for computing integrated information.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:55556
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.55556
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Arulalan.T
# {http://datacite.org/schema/kernel-3}affiliation
# National Centre for Medium Range Weather Forecasting
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Raghavendra Sreevathsa Mupparthy
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# UMRider: UMRider v1.0.2
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-06-14
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/arulalant/UMRider/tree/v1.0.2
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.594847
# {http://datacite.org/schema/kernel-3}version
# v1.0.2
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>NCMRWF's in-house development pleased to release UMRider's next operational release <strong>v1.0.2</strong> by focusing on NCUM ensembles post production along with other few new support.</p>
#
# <p><a href="https://zenodo.org/badge/latestdoi/20796/NCMRWF/UMRider"></a></p>
#
#
# <a class="anchor" href="#what-is-new-"><span class="octicon octicon-link"></span></a>what is new ?
#
# <ul>
# <li>Bugs fix</li>
# <li>12 extra user arguments features</li>
# <li>New extra vars </li>
# <li>checkout the <a href="https://github.com/NCMRWF/UMRider/blob/master/CHANGELOG.md#v102-2016-06-14">changlogs</a> and <a href="https://github.com/NCMRWF/UMRider/issues?q=milestone%3Av1.0.2+is%3Aclosed">milestone</a> of v1.0.2</li>
# <li>This v1.0.2 mainly target the following post productions along with the existing v1.0.1 supports
#
# <ul>
# <li><strong>NCUM EPS Global Post Production</strong></li>
# <li><strong>NCUM Tropical Cyclone Tracker input Production</strong></li>
# <li><strong>NCUM Regional Model Wind Energy Input Production</strong></li>
# <li><strong>NCUM Global Solar Energy Input Production</strong></li>
# </ul>
# </li>
# <li>Existing <em>v1.0.1</em> supports
#
# <ul>
# <li>NCUM Indian Region Post Production</li>
# <li>NCUM Global OSF Model Input Production</li>
# <li>NCUM Global HYCOM Model Input Production </li>
# <li>NCUM VSDB Input Production</li>
# <li>NCUM IMD MFI Input Production</li>
# </ul>
# </li>
# </ul>
#
#
# <a class="anchor" href="#v102-supports"><span class="octicon octicon-link"></span></a>v1.0.2 supports
#
# <ul>
# <li>
# <p>In this version v1.0.2 user will be able to control the following 37 arguments by exporting setup.cfg file into their environment variable called <strong>UMRIDER_SETUP</strong>. New arguments in this release are highlighted with bold. </p>
#
# <ul>
# <li><strong>UMtype</strong></li>
# <li><strong>UMInAnlFiles</strong></li>
# <li><strong>UMInShortFcstFiles</strong></li>
# <li>
# <strong>UMInLongFcstFiles</strong>,<br>
# </li>
# <li>inPath</li>
# <li>outPath</li>
# <li>tmpPath</li>
# <li> anl_step_hour</li>
# <li><strong>anl_aavars_reference_time</strong></li>
# <li><strong>anl_aavars_time_bounds</strong></li>
# <li><strong>fcst_step_hour</strong></li>
# <li><strong>start_long_fcst_hour</strong></li>
# <li><strong>end_long_fcst_hours_at_00z</strong></li>
# <li><strong>end_long_fcst_hours_at_12z</strong></li>
# <li>latitude</li>
# <li>longitude</li>
# <li>targetGridResolution</li>
# <li><strong>targetGridFile</strong></li>
# <li><strong>extraPolateMethod</strong></li>
# <li>pressureLevels</li>
# <li><strong>fillFullyMaskedVars</strong></li>
# <li><strong>soilFirstSecondFixedSurfaceUnit</strong></li>
# <li>startdate</li>
# <li>enddate</li>
# <li>loadg2utils</li>
# <li>overwriteFiles</li>
# <li>anlOutGrib2FilesNameStructure</li>
# <li>fcstOutGrib2FilesNameStructure</li>
# <li>createGrib2CtlIdxFiles</li>
# <li>convertGrib2FilestoGrib1Files</li>
# <li>grib1FilesNameSuffix</li>
# <li>removeGrib2FilesAfterGrib1FilesCreated</li>
# <li>createGrib1CtlIdxFiles</li>
# <li>debug </li>
# <li>setGrib2TableParameters</li>
# <li><strong>wgrib2Arguments</strong></li>
# <li>callBackScript</li>
# </ul>
# </li>
# <li><p>Also in this version v1.0.2 user will be able to control the variables by exporting vars.cfg file into their environment variable called <strong>UMRIDER_VARS</strong> . User defined variables and ordered will be retained in the out grib2 files (but pressure level variables comes first and followed by non-pressure level variables)</p></li>
# <li><p>User will be able to control would they like to get 1-hourly or 3-hourly or 6-hourly or 24-hourly <strong>analysis</strong> and/or <strong>forecast</strong> files. (Note that NCUM model produces every 3-hourly instantaneous/ average/ accumulated data. Depends upon user choice it will be  instantaneous or accumulated or averaged properly)</p></li>
# <li>
# <p>This v1.0.2 supports for </p>
#
# <ul>
# <li><strong>NCUM EPS Global Post Production</strong></li>
# <li><strong>NCUM Tropical Cyclone Tracker input Production</strong></li>
# <li><strong>NCUM Regional Model Wind Energy Input Production</strong></li>
# <li><strong>NCUM Global Solar Energy Input Production</strong></li>
# <li>NCUM Global Post Production</li>
# <li>NCUM Indian Region Post Production</li>
# <li>NCUM Global OSF Model Input Production</li>
# <li>NCUM Global HYCOM Model Input Production </li>
# <li>NCUM VSDB Input Production</li>
# <li>NCUM IMD MFI Input Production</li>
# </ul>
# </li>
# </ul>
#
# <p>Regards,</p>
#
# <p>Arulalan.T</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:55241
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:36Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.55241
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Luis Antonio Garnica
# {http://datacite.org/schema/kernel-3}affiliation
# University of Texas at El Paso
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# dbowlizer-app: DBOwlizer
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-06-08
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/cybershare/dbowlizer-app/tree/1.0
# {http://datacite.org/schema/kernel-3}version
# 1.0
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Initial release version of DBOWlizer</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:51325
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:37Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.51325
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Mihaljević-Brandt, Helena
# ...
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Massimiliano Assante
# {http://datacite.org/schema/kernel-3}affiliation
# Istituto di Scienza e Tecnologie dell'Informazione "A. Faedo" - CNR, Italy
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# gCube 4.7.0 - Custom Portal Handler v. 2.1.0
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Java
# {http://datacite.org/schema/kernel-3}subject
# Hybrid Data Infrastructure
# {http://datacite.org/schema/kernel-3}subject
# Social Networking
# {http://datacite.org/schema/kernel-3}subject
# gCube
# {http://datacite.org/schema/kernel-3}subject
# Graphical User Interface
# {http://datacite.org/schema/kernel-3}subject
# Data Management System
# {http://datacite.org/schema/kernel-3}subject
# Human Computer Interaction
# {http://datacite.org/schema/kernel-3}contributors
#
#
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/283644/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/675680/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654142/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654119/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/239019/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/288754/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654182/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/212488/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/283465/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654024/
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-10-13
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/gcube-team/gcube-releases/tree/master/portal/custom-portal-handler/2.1.0-4.7.0-131316
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.910468
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:gcube:mvn:org.gcube.portal:custom-portal-handler:2.1.0-4.7.0-131316
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1010650
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/gcube-system
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# European Union Public License 1.1
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>
# The gCube System - Custom Portal Handler<br>
# --------------------------------------------------<br>
#  <br>
# gCube Custom Portal Handler is a component that all portlets need to use to set the context where they running. <br>
# 		It also contains utils from creating community and organization with their layouts into liferay portal.<br>
#  <br>
#  <br>
# This software is part of the gCube Framework (https://www.gcube-system.org/): an<br>
# open-source software toolkit used for building and operating Hybrid Data<br>
# Infrastructures enabling the dynamic deployment of Virtual Research Environments<br>
# by favouring the realisation of reuse oriented policies.<br>
#  <br>
# The projects leading to this software have received funding from a series of<br>
# European Union programmes including:<br>
# * the Sixth Framework Programme for Research and Technological Development -<br>
# DILIGENT (grant no. 004260);<br>
# * the Seventh Framework Programme for research, technological development and<br>
# demonstration - D4Science (grant no. 212488), D4Science-II (grant no.<br>
# 239019),ENVRI (grant no. 283465), EUBrazilOpenBio (grant no. 288754), iMarine<br>
# (grant no. 283644);<br>
# * the H2020 research and innovation programme - BlueBRIDGE (grant no. 675680),<br>
# EGIEngage (grant no. 654142), ENVRIplus (grant no. 654182), Parthenos (grant<br>
# no. 654119), SoBigData (grant no. 654024);<br>
#  <br>
#  <br>
# Version<br>
# --------------------------------------------------<br>
#  <br>
# 2.1.0-4.7.0-131316 (2017-10-12)<br>
#  <br>
# Please see the file named "changelog.xml" in this directory for the release notes.<br>
#  <br>
#  <br>
# Authors<br>
# --------------------------------------------------<br>
#  <br>
# * Massimiliano Assante (massimiliano.assante-AT-isti.cnr.it), Istituto di Scienza e Tecnologie dell'Informazione "A. Faedo" - CNR, Pisa (Italy).<br>
# <br>
#  <br>
#  <br>
# Maintainers<br>
# -----------<br>
#  <br>
# * Massimiliano Assante (massimiliano.assante-AT-isti.cnr.it), Istituto di Scienza e Tecnologie dell'Informazione "A. Faedo" - CNR, Pisa (Italy).<br>
#  <br>
#  <br>
# Download information<br>
# --------------------------------------------------<br>
#  <br>
# Source code is available from SVN: <br>
#     http://svn.research-infrastructures.eu/public/d4science/gcube/trunk/portlal/custom-portal-handler<br>
#  <br>
# Binaries can be downloaded from the gCube website: <br>
#    https://www.gcube-system.org/<br>
#  <br>
#  <br>
# Installation<br>
# --------------------------------------------------<br>
#  <br>
# Installation documentation is available on-line in the gCube Wiki:<br>
#     https://wiki.gcube-system.org/gcube/index.php/<br>
#  <br>
#  <br>
# Documentation <br>
# --------------------------------------------------<br>
#  <br>
# Documentation is available on-line in the gCube Wiki:<br>
#     https://wiki.gcube-system.org/gcube/index.php/<br>
#     https://wiki.gcube-system.org/gcube/index.php/<br>
#  <br>
# Support <br>
# --------------------------------------------------<br>
#  <br>
# Bugs and support requests can be reported in the gCube issue tracking tool:<br>
#     https://support.d4science.org/projects/gcube/<br>
#  <br>
#  <br>
# Licensing<br>
# --------------------------------------------------<br>
#  <br>
# This software is licensed under the terms you may find in the file named "LICENSE" in this directory.<br>
#
# </p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1010639
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2019-11-01T07:14:45Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-gcube-system
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1010639
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Massimiliano Assante
# {http://datacite.org/schema/kernel-3}affiliation
# Istituto di Scienza e Tecnologie dell'Informazione "A. Faedo" - CNR, Italy
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# gCube 4.7.0 - social-dockbar-hook Hook v. 6.3.0
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Java
# {http://datacite.org/schema/kernel-3}subject
# Hybrid Data Infrastructure
# {http://datacite.org/schema/kernel-3}subject
# Social Networking
# {http://datacite.org/schema/kernel-3}subject
# gCube
# {http://datacite.org/schema/kernel-3}subject
# Graphical User Interface
# {http://datacite.org/schema/kernel-3}subject
# Data Management System
# {http://datacite.org/schema/kernel-3}subject
# Human Computer Interaction
# {http://datacite.org/schema/kernel-3}contributors
#
#
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/283644/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/675680/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654142/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654119/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/239019/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/288754/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654182/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/212488/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/FP7/283465/
# {http://datacite.org/schema/kernel-3}contributor
#
#
# {http://datacite.org/schema/kernel-3}contributorName
# European Commission
# {http://datacite.org/schema/kernel-3}nameIdentifier
# info:eu-repo/grantAgreement/EC/H2020/654024/
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-10-13
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:gcube:mvn:org.gcube.portal.plugins:social-dockbar-hook:6.3.0-4.7.0-130375
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://github.com/gcube-team/gcube-releases/tree/master/portal/social-dockbar-hook/6.3.0-4.7.0-130375
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1001454
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1010638
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/gcube-system
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# European Union Public License 1.1
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>
# The gCube System<br>
# ------------------------------------------------------------<br>
# <br>
# This software is part of the gCube Framework (https://www.gcube-system.org/): an<br>
# open-source software toolkit used for building and operating Hybrid Data<br>
# Infrastructures enabling the dynamic deployment of Virtual Research Environments<br>
# by favouring the realisation of reuse oriented policies.<br>
#  <br>
# The projects leading to this software have received funding from a series of<br>
# European Union programmes including:<br>
# * the Sixth Framework Programme for Research and Technological Development -<br>
# DILIGENT (grant no. 004260);<br>
# * the Seventh Framework Programme for research, technological development and<br>
# demonstration - D4Science (grant no. 212488), D4Science-II (grant no.<br>
# 239019),ENVRI (grant no. 283465), EUBrazilOpenBio (grant no. 288754), iMarine<br>
# (grant no. 283644);<br>
# * the H2020 research and innovation programme - BlueBRIDGE (grant no. 675680),<br>
# EGIEngage (grant no. 654142), ENVRIplus (grant no. 654182), Parthenos (grant<br>
# no. 654119), SoBigData (grant no. 654024);<br>
# <br>
# <br>
# Version<br>
# --------------------------------------------------<br>
# 6.3.0-4.7.0-130375 (2017-10-13)<br>
#  <br>
# Please see the file named "changelog.xml" in this directory for the release notes.<br>
# <br>
# <br>
# Authors<br>
# -------<br>
# <br>
#  <br>
# Massimiliano Assante (massimiliano.assante-AT-isti.cnr.it), Istituto di Scienza e Tecnologie dell'Informazione "A. Faedo" - CNR, Pisa (Italy).<br>
# <br>
# <br>
# Maintainers<br>
# -----------<br>
#  <br>
# Massimiliano Assante (massimiliano.assante-AT-isti.cnr.it), Istituto di Scienza e Tecnologie dell'Informazione "A. Faedo" - CNR, Pisa (Italy).<br>
#  <br>
#  <br>
# Documentation<br>
# -------------<br>
# <br>
# Documentation is available on - line from the Projects Documentation wiki:<br>
# <br>
#  {gcube.wikiRoot}/gcube/index.php/UserManagement_Core<br>
# <br>
# <br>
# Support <br>
# --------------------------------------------------<br>
# Bugs and support requests can be reported in the gCube issue tracking tool:<br>
#     https://support.d4science.org/projects/gcube/<br>
#  <br>
#  <br>
# Licensing<br>
# --------------------------------------------------<br>
# This software is licensed under the terms you may find in the file named "LICENSE" in this directory.<br>
#
# </p>
# {http://www.openarchives.org/OAI/2.0/}resumptionToken
# .eJwdjU8LgjAcQL_L7yyhcysTPGQlJB3SLP9cZOmSMYdDBxrid896x_cOb4aBsRpcc7NDNra3mFgO2iPiYAOGqu_atuRrhlMWWEUWkiglIpZPM0eNf_jzca7TJX3JVsdnbUYPda9lcEwSXyVC4dwKg2L0PDBA0YaBiwwQI-2bAdwZJNO0ppreevbm07rpKC9_ouKawbJ8AYkhMck.XgaEkw.W0tSpDxsaipurl-mlA3V3znxkzk

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# Muestra sólo el identificador y las palabras clave (subject)

# %%
import xml.etree.ElementTree as ET
import requests

# Hago la petición al servidor
oai = requests.get('https://zenodo.org/oai2d?verb=ListRecords&metadataPrefix=oai_datacite')

# Creo un xmlTree 
xmlTree = ET.fromstring(oai.text)

# Recorro el xmlTree:
# busco los elementos 'record'
# y los sub-elementos 'identifier' y 'subject'
records = xmlTree.findall('.//{http://www.openarchives.org/OAI/2.0/}record')
for el in records:
    for identifier in el.findall('.//{http://datacite.org/schema/kernel-3}identifier'):
        print("Identifier:",identifier.text)
    for subject in el.findall('.//{http://datacite.org/schema/kernel-3}subject'):          
        print("Subject:",subject.text)
    print()
# Out:
# Identifier: 10.5281/zenodo.3367294
# Subject: civil service
# Subject: public service law
# Subject: government administration
# Subject: state
# Subject: law
#
# Identifier: https://zenodo.org/record/3523810
# Subject: Animalia
# Subject: Chordata
# Subject: Actinopterygii
# Subject: Characiformes
# Subject: Characidae
# Subject: Aphyocharax
# Subject: Freshwater
# Subject: integrative taxonomy
# Subject: Neotropical ichthyology
# Subject: sexual dimorphism
#
# Identifier: https://zenodo.org/record/3523800
# Subject: hybrid
# Subject: molecular
# Subject: Nepeta
# Subject: phylogeny
# Subject: Turkey
#
# Identifier: https://zenodo.org/record/3523790
# Subject: Plantae
# Subject: Tracheophyta
# Subject: Magnoliopsida
# Subject: Ericales
# Subject: Ericaceae
# Subject: Rhododendron
# Subject: Ericaceae
# Subject: new species
# Subject: phylogeny
# Subject: Rhododendron
#
# Identifier: https://zenodo.org/record/3523788
# Subject: Plantae
# Subject: Tracheophyta
# Subject: Magnoliopsida
# Subject: Ericales
# Subject: Ericaceae
# Subject: Rhododendron
# Subject: Ericaceae
# Subject: new species
# Subject: phylogeny
# Subject: Rhododendron
#
# Identifier: https://zenodo.org/record/3523784
# Subject: Plantae
# Subject: Tracheophyta
# Subject: Magnoliopsida
# Subject: Ericales
# Subject: Ericaceae
# Subject: Rhododendron
# Subject: Rhododendron tschonoskii
# Subject: Ericaceae
# Subject: new species
# Subject: phylogeny
# Subject: Rhododendron
#
# Identifier: https://zenodo.org/record/3523782
# Subject: Plantae
# Subject: Tracheophyta
# Subject: Magnoliopsida
# Subject: Ericales
# Subject: Ericaceae
# Subject: Rhododendron
# Subject: Rhododendron tschonoskii
# Subject: Ericaceae
# Subject: new species
# Subject: phylogeny
# Subject: Rhododendron
#
# Identifier: https://zenodo.org/record/3523780
# Subject: Plantae
# Subject: Tracheophyta
# Subject: Magnoliopsida
# Subject: Ericales
# Subject: Ericaceae
# Subject: Rhododendron
# Subject: Rhododendron tschonoskii
# Subject: Ericaceae
# Subject: Biodiversity
# Subject: Araneoidea
# Subject: Systematics
# Subject: Tetragnathinae
#
# Identifier: https://zenodo.org/record/3522503
# Subject: Animalia
# Subject: Arthropoda
# Subject: Arachnida
# Subject: Araneae
# Subject: Tetragnathidae
# Subject: Tetragnatha
# Subject: Tetragnatha bogotensis
# Subject: Biodiversity
# Subject: Araneoidea
# Subject: Systematics
# Subject: Tetragnathinae
#
# Identifier: 10.5281/zenodo.3520992
# Subject: Biodiversity
# Subject: Taxonomy
# Subject: Animalia
# Subject: Cnidaria
# Subject: Hydrozoa
# Subject: Anthoathecata
# Subject: Candelabridae
# Subject: Candelabrum
#
# Identifier: 10.5281/zenodo.3520990
# Subject: Biodiversity
# Subject: Taxonomy
# Subject: Animalia
# Subject: Cnidaria
# Subject: Hydrozoa
# Subject: Anthoathecata
# Subject: Candelabridae
# Subject: Candelabrum
#
# Identifier: 10.5281/zenodo.3520898
# Subject: Biodiversity
# Subject: Taxonomy
# Subject: Animalia
# Subject: Arthropoda
# Subject: Insecta
# Subject: Plecoptera
#
# Identifier: 10.5281/zenodo.3520894
# Subject: Biodiversity
# Subject: Taxonomy
# Subject: Animalia
# Subject: Arthropoda
# Subject: Insecta
# Subject: Plecoptera
#
# Identifier: 10.5281/zenodo.3520789
# Subject: Biodiversity
# Subject: Taxonomy
# Subject: Animalia
# Subject: Arthropoda
# Subject: Insecta
# Subject: Odonata
# Subject: Lestidae
# Subject: Lestes
#
# Identifier: 10.5281/zenodo.3520762
# Subject: Biodiversity
# Subject: Taxonomy
#
# Identifier: 10.5281/zenodo.3520191
# Subject: educomunicação
# Subject: inclusão
# Subject: acessibilidade
#
# Identifier: 10.5281/zenodo.3520183
# Subject: educomunicação
# Subject: inclusão
# Subject: acessibilidade
#
# Identifier: 10.5281/zenodo.3519944
#
# Identifier: 10.5281/zenodo.3519468
# Subject: traditional narrative

# %% [markdown]
# ## Filtros

# %% [markdown]
# Registros entre dos fechas

# %%
import xml.etree.ElementTree as ET

bounds = "&from='2017-01-01'&until='2017-12-31'" #Para filtrar por fechas
oai = requests.get('https://zenodo.org/oai2d?verb=ListRecords&metadataPrefix=oai_datacite'+bounds)
xmlTree = ET.fromstring(oai.text)
iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag)
    print(elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH
#
#
# {http://www.openarchives.org/OAI/2.0/}responseDate
# 2019-12-27T22:24:22Z
# {http://www.openarchives.org/OAI/2.0/}request
# https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}ListRecords
#
#
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1134089
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-30T12:03:39Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1134089
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Opetus- ja kulttuuriministeriö
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Yliopistojen tiedonkeruukäsikirja 2016
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2016
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# http://www.yso.fi/onto/yso/p9543
# {http://datacite.org/schema/kernel-3}subject
# http://www.yso.fi/onto/juho/p4137
# {http://datacite.org/schema/kernel-3}subject
# http://www.yso.fi/onto/juho/p4602
# {http://datacite.org/schema/kernel-3}subject
# http://www.yso.fi/onto/juho/p1023
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2016-12-23
# {http://datacite.org/schema/kernel-3}language
# fi
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://confluence.csc.fi/download/attachments/36603300/Yliopistojen%20tiedonkeruuk%C3%A4sikirja%202016%20%28PDF%29.pdf?version=1&modificationDate=1482479418428&api=v2
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1134088
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0 International
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Unofficial, archived copy of &quot;OKM:n yliopistojen tiedonkeruukäsikirja 2016&quot;; publication statistics handbook for Finnish universities.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1133556
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-28T10:16:18Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1133556
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Feitosa, Daniel
# {http://datacite.org/schema/kernel-3}affiliation
# University of Groningen
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Ampatzoglou, Apostolos
# {http://datacite.org/schema/kernel-3}affiliation
# University of Groningen
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Avgeriou, Paris
# {http://datacite.org/schema/kernel-3}affiliation
# University of Groningen
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Nakagawa, Elisa Yumi
# {http://datacite.org/schema/kernel-3}affiliation
# University of São Paulo
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Supplementary Material: "Correlating Pattern Grime and Quality Attributes"
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# supplementary material
# {http://datacite.org/schema/kernel-3}subject
# design patterns
# {http://datacite.org/schema/kernel-3}subject
# pattern grime
# {http://datacite.org/schema/kernel-3}subject
# quality attributes
# {http://datacite.org/schema/kernel-3}subject
# industrial case study
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-28
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1133552
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0 International
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p><strong>Supplementary Material</strong></p>
#
# <p>This material regards the paper entitled &quot;<em>Correlating Pattern Grime and Quality Attributes</em>&quot;.</p>
#
# <p>The spreadsheet contains the complete descriptive statistics of the data used to all research questions addressed in the study reported in the aforementioned paper. It also contains the results of the statistical analyses performed based on the dataset.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1133553
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-28T10:16:15Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1133553
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Feitosa, Daniel
# {http://datacite.org/schema/kernel-3}affiliation
# University of Groningen
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Ampatzoglou, Apostolos
# {http://datacite.org/schema/kernel-3}affiliation
# University of Groningen
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Avgeriou, Paris
# {http://datacite.org/schema/kernel-3}affiliation
# University of Groningen
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Nakagawa, Elisa Yumi
# {http://datacite.org/schema/kernel-3}affiliation
# University of São Paulo
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Supplementary Material: "Correlating Pattern Grime and Quality Attributes"
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# supplementary material
# {http://datacite.org/schema/kernel-3}subject
# design patterns
# {http://datacite.org/schema/kernel-3}subject
# pattern grime
# {http://datacite.org/schema/kernel-3}subject
# quality attributes
# {http://datacite.org/schema/kernel-3}subject
# industrial case study
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-28
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1133552
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution 4.0 International
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p><strong>Supplementary Material</strong></p>
#
# <p>This material regards the paper entitled &quot;<em>Correlating Pattern Grime and Quality Attributes</em>&quot;.</p>
#
# <p>The spreadsheet contains the complete descriptive statistics of the data used to all research questions addressed in the study reported in the aforementioned paper. It also contains the results of the statistical analyses performed based on the dataset.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1129485
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-24T19:37:48Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1129485
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# BOISSELIER,Patrick
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# KOHLER, François
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# les coûts complets, principes et fondements
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# comptabilité analytique
# {http://datacite.org/schema/kernel-3}subject
# contrôle de gestion
# {http://datacite.org/schema/kernel-3}subject
# coût complet
# {http://datacite.org/schema/kernel-3}subject
# répartition des charges
# {http://datacite.org/schema/kernel-3}subject
# système d'information
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-24
# {http://datacite.org/schema/kernel-3}language
# fr
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1129484
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution Non Commercial 4.0 International
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Le&ccedil;on de calcul du co&ucirc;t complet destin&eacute; aux &eacute;tudiants de 2&egrave;me ann&eacute;e de licence en sciences &eacute;conomiques et de gestion&nbsp; et&nbsp; peut aussi &ecirc;tre utile aux &eacute;tudiants dans diff&eacute;rents domaines souhaitant apprendre &agrave; calculer les co&ucirc;ts des produits et des services.</p>
#
# <p>La&nbsp; le&ccedil;on int&egrave;gre une vid&eacute;o comportant un exemple illustratif r&eacute;alis&eacute;e le&nbsp;18 Janvier 2006 d&#39;une dur&eacute;e de&nbsp;17 min r&eacute;alis&eacute;e par&nbsp;KOHLER Fran&ccedil;ois</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1129477
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-24T18:04:16Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1129477
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Atef HASNI
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# Les variables en java
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# variables, java, exercice, activité
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-24
# {http://datacite.org/schema/kernel-3}language
# fr
# {http://datacite.org/schema/kernel-3}resourceType
# None
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1129476
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Creative Commons Attribution-NonCommercial-ShareAlike
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# <p>Une petite d&eacute;marche pour exprimer la syntaxe d&#39;utilisation des variables en java avec une petite activit&eacute;.</p>
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1126992
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-22T13:54:41Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1126992
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shelley, James J.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Delaval, Aurélien
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Le, Matthew C.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# FIGURE 29 in A revision of the grunter genus Syncomistes (Teleostei, Terapontidae, Syncomistes) with descriptions of seven new species from the Kimberley region, northwestern Australia
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Chordata
# {http://datacite.org/schema/kernel-3}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-3}subject
# Perciformes
# {http://datacite.org/schema/kernel-3}subject
# Terapontidae
# {http://datacite.org/schema/kernel-3}subject
# Syncomistes
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-22
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/0E0E0456FFA0FF9627855DF3FC0DF9E8
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4367.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:F2377C2EFFEEFFC527125B50FFE8FF9B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/record/1125303
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1126991
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 29.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1126986
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-22T13:54:35Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1126986
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shelley, James J.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Delaval, Aurélien
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Le, Matthew C.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# FIGURE 27 in A revision of the grunter genus Syncomistes (Teleostei, Terapontidae, Syncomistes) with descriptions of seven new species from the Kimberley region, northwestern Australia
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Chordata
# {http://datacite.org/schema/kernel-3}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-3}subject
# Perciformes
# {http://datacite.org/schema/kernel-3}subject
# Terapontidae
# {http://datacite.org/schema/kernel-3}subject
# Syncomistes
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-22
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/0E0E0456FFA7FF8B27855AE8FB1BF9D4
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4367.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:F2377C2EFFEEFFC527125B50FFE8FF9B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/record/1125303
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1126985
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 27.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1126982
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-22T13:54:32Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1126982
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shelley, James J.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Delaval, Aurélien
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Le, Matthew C.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# FIGURE 26 in A revision of the grunter genus Syncomistes (Teleostei, Terapontidae, Syncomistes) with descriptions of seven new species from the Kimberley region, northwestern Australia
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Chordata
# {http://datacite.org/schema/kernel-3}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-3}subject
# Perciformes
# {http://datacite.org/schema/kernel-3}subject
# Terapontidae
# {http://datacite.org/schema/kernel-3}subject
# Syncomistes
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-22
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/0E0E0456FFA7FF8B27855AE8FB1BF9D4
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4367.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:F2377C2EFFEEFFC527125B50FFE8FF9B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/record/1125303
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1126981
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 26.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1126980
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-22T13:54:27Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1126980
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shelley, James J.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Delaval, Aurélien
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Le, Matthew C.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# FIGURE 25 in A revision of the grunter genus Syncomistes (Teleostei, Terapontidae, Syncomistes) with descriptions of seven new species from the Kimberley region, northwestern Australia
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Chordata
# {http://datacite.org/schema/kernel-3}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-3}subject
# Perciformes
# {http://datacite.org/schema/kernel-3}subject
# Terapontidae
# {http://datacite.org/schema/kernel-3}subject
# Syncomistes
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-22
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/0E0E0456FFADFF8C278558A8FF36FEFE
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4367.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:F2377C2EFFEEFFC527125B50FFE8FF9B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/record/1125303
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1126979
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 25.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1126976
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-22T13:54:24Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1126976
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shelley, James J.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Delaval, Aurélien
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Le, Matthew C.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# FIGURE 24 in A revision of the grunter genus Syncomistes (Teleostei, Terapontidae, Syncomistes) with descriptions of seven new species from the Kimberley region, northwestern Australia
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Chordata
# {http://datacite.org/schema/kernel-3}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-3}subject
# Perciformes
# {http://datacite.org/schema/kernel-3}subject
# Terapontidae
# {http://datacite.org/schema/kernel-3}subject
# Syncomistes
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-22
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/0E0E0456FFADFF8C278558A8FF36FEFE
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4367.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:F2377C2EFFEEFFC527125B50FFE8FF9B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/record/1125303
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1126975
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 24.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1126962
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-22T13:54:07Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1126962
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shelley, James J.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Delaval, Aurélien
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Le, Matthew C.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# FIGURE 20 in A revision of the grunter genus Syncomistes (Teleostei, Terapontidae, Syncomistes) with descriptions of seven new species from the Kimberley region, northwestern Australia
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Chordata
# {http://datacite.org/schema/kernel-3}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-3}subject
# Perciformes
# {http://datacite.org/schema/kernel-3}subject
# Terapontidae
# {http://datacite.org/schema/kernel-3}subject
# Syncomistes
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-22
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/0E0E0456FFD7FFFB27855E46FBF8FD3C
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4367.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:F2377C2EFFEEFFC527125B50FFE8FF9B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/record/1125303
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1126961
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 20
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1126956
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-22T13:54:01Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1126956
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shelley, James J.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Delaval, Aurélien
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Le, Matthew C.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# FIGURE 18 in A revision of the grunter genus Syncomistes (Teleostei, Terapontidae, Syncomistes) with descriptions of seven new species from the Kimberley region, northwestern Australia
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Chordata
# {http://datacite.org/schema/kernel-3}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-3}subject
# Perciformes
# {http://datacite.org/schema/kernel-3}subject
# Terapontidae
# {http://datacite.org/schema/kernel-3}subject
# Syncomistes
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-22
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/0E0E0456FFDAFFFC27855BC8FBFEFE4B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4367.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:F2377C2EFFEEFFC527125B50FFE8FF9B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/record/1125303
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1126955
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 18.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1126952
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-22T13:53:57Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1126952
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shelley, James J.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Delaval, Aurélien
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Le, Matthew C.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# FIGURE 17 in A revision of the grunter genus Syncomistes (Teleostei, Terapontidae, Syncomistes) with descriptions of seven new species from the Kimberley region, northwestern Australia
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Chordata
# {http://datacite.org/schema/kernel-3}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-3}subject
# Perciformes
# {http://datacite.org/schema/kernel-3}subject
# Terapontidae
# {http://datacite.org/schema/kernel-3}subject
# Syncomistes
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-22
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/0E0E0456FFC0FFF627855D0BFEAFF868
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4367.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:F2377C2EFFEEFFC527125B50FFE8FF9B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/record/1125303
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1126951
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 17.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1126948
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-22T13:53:53Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1126948
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shelley, James J.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Delaval, Aurélien
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Le, Matthew C.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# FIGURE 16 in A revision of the grunter genus Syncomistes (Teleostei, Terapontidae, Syncomistes) with descriptions of seven new species from the Kimberley region, northwestern Australia
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Chordata
# {http://datacite.org/schema/kernel-3}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-3}subject
# Perciformes
# {http://datacite.org/schema/kernel-3}subject
# Terapontidae
# {http://datacite.org/schema/kernel-3}subject
# Syncomistes
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-22
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/0E0E0456FFC0FFF627855D0BFEAFF868
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4367.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:F2377C2EFFEEFFC527125B50FFE8FF9B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/record/1125303
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1126947
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 16.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1126946
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-22T13:53:49Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1126946
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Shelley, James J.
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Delaval, Aurélien
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Le, Matthew C.
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# FIGURE 15 in A revision of the grunter genus Syncomistes (Teleostei, Terapontidae, Syncomistes) with descriptions of seven new species from the Kimberley region, northwestern Australia
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Chordata
# {http://datacite.org/schema/kernel-3}subject
# Actinopterygii
# {http://datacite.org/schema/kernel-3}subject
# Perciformes
# {http://datacite.org/schema/kernel-3}subject
# Terapontidae
# {http://datacite.org/schema/kernel-3}subject
# Syncomistes
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-22
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/0E0E0456FFC7FFEB27855F6EFCCAF99C
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4367.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:F2377C2EFFEEFFC527125B50FFE8FF9B
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/record/1125303
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1126945
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 15.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1126942
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-22T13:53:44Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# ...
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1119229
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-20T06:46:31Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1119229
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Yasunaga, Tomohide
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Yamada, Kazutaka
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Tsai, Jing-Fu
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# FIGURE 11 in Taxonomic review of the plant bug subfamily Isometopinae for Taiwan and Japanese Southwest Islands, with descriptions of new taxa (Hemiptera: Heteroptera: Miridae: Isometopinae)
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Hemiptera
# {http://datacite.org/schema/kernel-3}subject
# Miridae
# {http://datacite.org/schema/kernel-3}subject
# Myiomma
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-20
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/6A6F87E8FF958717FF12FC5EFA88FE2C
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4365.4.3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:9656FF90FF92871EFF85FFA9FFAAFFFC
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/record/1119207
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1119228
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 11. Map showing distributions of Isometopus and Myiomma species known from southwestern Japan to Taiwan.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1119227
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-20T06:46:28Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1119227
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Yasunaga, Tomohide
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Yamada, Kazutaka
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Tsai, Jing-Fu
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# FIGURE 10 in Taxonomic review of the plant bug subfamily Isometopinae for Taiwan and Japanese Southwest Islands, with descriptions of new taxa (Hemiptera: Heteroptera: Miridae: Isometopinae)
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Hemiptera
# {http://datacite.org/schema/kernel-3}subject
# Miridae
# {http://datacite.org/schema/kernel-3}subject
# Kohnometopus
# {http://datacite.org/schema/kernel-3}subject
# Myiomma
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-20
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/6A6F87E8FF90871DFF12FA46FC37FEC3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/6A6F87E8FF9E8712FF12FF3EFC8FF872
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4365.4.3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:9656FF90FF92871EFF85FFA9FFAAFFFC
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/record/1119207
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1119226
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 10. Final (fifth) immature form of Astroscopometops grillocephalus (Miyamoto, Yasunaga &amp; Hayashi) (A–D), Myiomma sp. (either minutum or samuelsoni) (E–G), and Kohnometopus fraxini Yasunaga (H). A, E, F &amp; H, Dorsal habitus; B, head with pro-ocular horn (left); C, pronotal projections (right); D &amp; G, surface structure and vestiture on mesonotum.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1119223
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-20T06:46:19Z
# {http://www.openarchives.org/OAI/2.0/}setSpec
# user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1119223
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Yasunaga, Tomohide
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Yamada, Kazutaka
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Tsai, Jing-Fu
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# FIGURE 8 in Taxonomic review of the plant bug subfamily Isometopinae for Taiwan and Japanese Southwest Islands, with descriptions of new taxa (Hemiptera: Heteroptera: Miridae: Isometopinae)
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Hemiptera
# {http://datacite.org/schema/kernel-3}subject
# Miridae
# {http://datacite.org/schema/kernel-3}subject
# Alcecoris
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-20
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/6A6F87E8FF9C870EFF12F8B9FC7EFCC4
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4365.4.3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:9656FF90FF92871EFF85FFA9FFAAFFFC
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/record/1119207
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1119222
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 8. Scanning electron micrographs of Alcecoris cochlearatus sp. nov., holotype female. A. Head and anterior pronotum, dorsal view. B. Antenna. C. Anterior body, ventral view. D. Scutellum and forewing, dorsal view. E. Ditto, metathoracic scent efferent system (left). F. Mesotarsus.
# {http://www.openarchives.org/OAI/2.0/}record
#
#
# {http://www.openarchives.org/OAI/2.0/}header
#
#
# {http://www.openarchives.org/OAI/2.0/}identifier
# oai:zenodo.org:1119221
# {http://www.openarchives.org/OAI/2.0/}datestamp
# 2017-12-20T06:46:15Z
# {http://www.openarchives.org/OAI/2.0/}metadata
#
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite
#
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality
# true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion
# 3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol
# CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload
#
#
# {http://datacite.org/schema/kernel-3}resource
#
#
# {http://datacite.org/schema/kernel-3}identifier
# 10.5281/zenodo.1119221
# {http://datacite.org/schema/kernel-3}creators
#
#
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Yasunaga, Tomohide
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Yamada, Kazutaka
# {http://datacite.org/schema/kernel-3}creator
#
#
# {http://datacite.org/schema/kernel-3}creatorName
# Tsai, Jing-Fu
# {http://datacite.org/schema/kernel-3}titles
#
#
# {http://datacite.org/schema/kernel-3}title
# FIGURE 7 in Taxonomic review of the plant bug subfamily Isometopinae for Taiwan and Japanese Southwest Islands, with descriptions of new taxa (Hemiptera: Heteroptera: Miridae: Isometopinae)
# {http://datacite.org/schema/kernel-3}publisher
# Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear
# 2017
# {http://datacite.org/schema/kernel-3}subjects
#
#
# {http://datacite.org/schema/kernel-3}subject
# Biodiversity
# {http://datacite.org/schema/kernel-3}subject
# Taxonomy
# {http://datacite.org/schema/kernel-3}subject
# Animalia
# {http://datacite.org/schema/kernel-3}subject
# Arthropoda
# {http://datacite.org/schema/kernel-3}subject
# Insecta
# {http://datacite.org/schema/kernel-3}subject
# Hemiptera
# {http://datacite.org/schema/kernel-3}subject
# Miridae
# {http://datacite.org/schema/kernel-3}subject
# Myiomma
# {http://datacite.org/schema/kernel-3}dates
#
#
# {http://datacite.org/schema/kernel-3}date
# 2017-12-20
# {http://datacite.org/schema/kernel-3}resourceType
# Figure
# {http://datacite.org/schema/kernel-3}relatedIdentifiers
#
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/6A6F87E8FF91871DFF12FEC6FBC6FBA4
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/6A6F87E8FF958717FF12FC5EFA88FE2C
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# http://treatment.plazi.org/id/6A6F87E8FF9E8712FF12FF3EFC8FF872
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.11646/zootaxa.4365.4.3
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# urn:lsid:plazi.org:pub:9656FF90FF92871EFF85FFA9FFAAFFFC
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# https://zenodo.org/record/1119207
# {http://datacite.org/schema/kernel-3}relatedIdentifier
# 10.5281/zenodo.1119220
# {http://datacite.org/schema/kernel-3}rightsList
#
#
# {http://datacite.org/schema/kernel-3}rights
# Open Access
# {http://datacite.org/schema/kernel-3}descriptions
#
#
# {http://datacite.org/schema/kernel-3}description
# FIGURE 7. Scanning electron micrographs of Myiomma spp. A. M. austroccidens sp. nov., male from Amami-Oshima, left lateral view. B. Ditto, metathoracic scent efferent system (left). C. Ditto, pygophore with left paramere, ventral view. D. M. kentingense sp. nov., male from Pingtung, Taiwan, dorsal habitus. E. Ditto, ventral view.F. Ditto, protarsus. G. M. samuelsoni Miyamoto, female from Ishigaki Island, dorsal view. H. Ditto, male from Okinawa Island, ventral view. I. Ditto, male, dorsal view.J. Ditto, metatarsus.
# {http://www.openarchives.org/OAI/2.0/}resumptionToken
# .eJxVjEsLgkAYRf_Lt5ZwfIAKLpJQCqK0fG5kylEHnZQZe6D439N23eU9594JBCEFWPIGGaahIc00EFIV1VR0CcSdd22b04XDLnFRlhx0P9abgEVyqlTO9hd5f_VEfPPqMXDbMI3r4BIVp5uc6QFyvCNrxtC3bZCgxxUBS5GgeWNeCbAmKHnHlvOecEaFoC-yaIwMuMADPnNS0s9CO0zztbjTYeXPx0Db_9E8fwGFqD_Y.XgaElg.SJaBPub4uZRkofodCThnFpbeAkg

# %% [markdown]
# ### GetRecord
#
# This verb is used to retrieve an individual metadata record from a repository. Required arguments specify the identifier of the item from which the record is requested and the format of the metadata that should be included in the record. Depending on the level at which a repository tracks deletions, a header with a "deleted" value for the status attribute may be returned, in case the metadata format specified by the metadataPrefix is no longer available from the repository or from the specified item.
#
# Obtener objeto digital de ese recurso

# %%
import xml.etree.ElementTree as ET
import urllib
#https://zenodo.org/oai2d?verb=GetRecord&metadataPrefix=oai_dc&identifier=oai:zenodo.org:252670
oai = requests.get('https://zenodo.org/oai2d?verb=GetRecord&metadataPrefix=oai_datacite&identifier=oai:zenodo.org:252977')
xmlTree = ET.fromstring(oai.text)
ns = {'oai' : 'http://www.openarchives.org/OAI/2.0/'}

#iterator = xmlTree.iter()
#for elem in iterator:
 #   print(elem.tag)
 #   print(elem.text)

for tags in xmlTree.findall('.//',ns):
    print (tags.tag+": ",tags.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}responseDate:  2019-12-27T22:24:24Z
# {http://www.openarchives.org/OAI/2.0/}request:  https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}GetRecord:
#
# {http://www.openarchives.org/OAI/2.0/}record:
#
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier:  oai:zenodo.org:252977
# {http://www.openarchives.org/OAI/2.0/}datestamp:  2019-04-10T04:00:17Z
# {http://www.openarchives.org/OAI/2.0/}setSpec:  user-biosyslit
# {http://www.openarchives.org/OAI/2.0/}metadata:
#
# {http://schema.datacite.org/oai/oai-1.0/}oai_datacite:
#
# {http://schema.datacite.org/oai/oai-1.0/}isReferenceQuality:  true
# {http://schema.datacite.org/oai/oai-1.0/}schemaVersion:  3.1
# {http://schema.datacite.org/oai/oai-1.0/}datacentreSymbol:  CERN.ZENODO
# {http://schema.datacite.org/oai/oai-1.0/}payload:
#
# {http://datacite.org/schema/kernel-3}resource:
#
# {http://datacite.org/schema/kernel-3}identifier:  10.5281/zenodo.252977
# {http://datacite.org/schema/kernel-3}creators:
#
# {http://datacite.org/schema/kernel-3}creator:
#
# {http://datacite.org/schema/kernel-3}creatorName:  Harzhauser, Mathias
# {http://datacite.org/schema/kernel-3}creator:
#
# {http://datacite.org/schema/kernel-3}creatorName:  Landau, Bernard
# {http://datacite.org/schema/kernel-3}titles:
#
# {http://datacite.org/schema/kernel-3}title:  FIGURE 13A 1 –A 5 in A revision of the Neogene Conidae and Conorbidae (Gastropoda) of the Paratethys Sea
# {http://datacite.org/schema/kernel-3}publisher:  Zenodo
# {http://datacite.org/schema/kernel-3}publicationYear:  2016
# {http://datacite.org/schema/kernel-3}subjects:
#
# {http://datacite.org/schema/kernel-3}subject:  Biodiversity
# {http://datacite.org/schema/kernel-3}subject:  Taxonomy
# {http://datacite.org/schema/kernel-3}subject:  Animalia
# {http://datacite.org/schema/kernel-3}subject:  Kalloconus
# {http://datacite.org/schema/kernel-3}dates:
#
# {http://datacite.org/schema/kernel-3}date:  2016-12-31
# {http://datacite.org/schema/kernel-3}resourceType:  Figure
# {http://datacite.org/schema/kernel-3}alternateIdentifiers:
#
# {http://datacite.org/schema/kernel-3}alternateIdentifier:  https://zenodo.org/record/252977
# {http://datacite.org/schema/kernel-3}relatedIdentifiers:
#
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  http://treatment.plazi.org/id/373F87D7FFDCFFCDFF5FA9D9FC3046B3
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  http://treatment.plazi.org/id/373F87D7FFDBFFCAFF5FA8E1FA0B4762
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  http://treatment.plazi.org/id/373F87D7FFDBFFC8FF5FAE2DFDC5443D
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  10.11646/zootaxa.4210.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  urn:lsid:plazi.org:pub:CB06FFAFFF9FFF8EFFC8A876FF89416A
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  https://zenodo.org/record/252966
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  10.11646/zootaxa.4210.1.1
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  https://zenodo.org/record/252966
# {http://datacite.org/schema/kernel-3}relatedIdentifier:  https://zenodo.org/communities/biosyslit
# {http://datacite.org/schema/kernel-3}rightsList:
#
# {http://datacite.org/schema/kernel-3}rights:  Open Access
# {http://datacite.org/schema/kernel-3}descriptions:
#
# {http://datacite.org/schema/kernel-3}description:  FIGURE 13A 1 –A 5. Kalloconus ponderovagus (Sacco, 1893), Niederkreuzstetten (Austria), NHMW 1849/0004/0016, holotype. 13B 1 –B 3. Niederkreuzstetten (Austria), NHMW A991. 13C 1 –C 4. Kalloconus pseudohungaricus nov. sp., Lăpugiu de Sus (Romania), NHMW 1868/0001/0380a, paratype. 13D. Lăpugiu de Sus (Romania), Kalloconus pseudohungaricus nov. sp., NHMW 1868/0001/0380d, paratype. 13E 1 –E 3. Kalloconus pseudohungaricus nov. sp., Lăpugiu de Sus (Romania), NHMW 1868/0001/0380b, holotype. 13F 1 –F 2. Lăpugiu de Sus (Romania), Kalloconus pseudohungaricus nov. sp., NHMW 1868/0001/ 0380c, paratype. 13G 1 –G 5. Kalloconus tietzei (Hoernes &amp; Auinger, 1879), NHMW 1847/0046/0004, Szob (Hungary), holotype.

# %%
import xml.etree.ElementTree as ET
#https://zenodo.org/oai2d?verb=GetRecord&metadataPrefix=oai_dc&identifier=oai:zenodo.org:252670
headers = {'Accept': 'application/rdf+xml;q=0.5'} #Type of response accpeted
r = requests.post('https://dx.doi.org/10.5281/zenodo.252363', headers=headers) #POST with headers
print(r.text)

# %% [markdown]
# ## APIs específicas

# %% [markdown]
# El protocolo OAI-PMH ofrece una serie de funcionalidades genéricas e interoperables entre distintos repositorios. Sin embargo, existen ciertas limitaciones que no nos permiten automatizar todo lo necesario para analizar un gran número de dataset. Para ello, tenemos que recurrir a APIs específicas de los repositorios con los que trabajamos.
#
# Zenodo proporciona una API bastante completa que complementa al protocolo OAI-PMH. En el siguiente enlace podemos ver su especificación y algunos ejemplos con curl y python.
#
# http://developers.zenodo.org/
#
# Entre otras cosas, podemos automatizar el proceso de publicación, descargar archivos, etc.
#
# También, obteniendo el DOI de un recurso, podemos resolverlo para obtener cierta información específica, como la URL del objeto digital entre otras.

# %%
import json
#Buscamos datasets específicos-
oai = requests.get('https://zenodo.org/oai2d?verb=ListRecords&metadataPrefix=datacite3')
oaiTree = ET.fromstring(oai.text)
#for i in oaiTree.iter():
#    print(i.tag)
records = oaiTree.findall('.//{http://www.openarchives.org/OAI/2.0/}record')
for e in records:
    for subject in e.findall('.//{http://datacite.org/schema/kernel-3}subject'):
        if "Animalia" in subject.text:
            print("Title: "+e.findall('.//{http://datacite.org/schema/kernel-3}title')[0].text)
            identifier = e.findall('.//{http://datacite.org/schema/kernel-3}identifier')[0].text
            print(identifier)
            print('\n')

# %%
     
headers = {'accept': 'application/json'}
# uno de los records que me ha impreso el comando de la celda de arriba
r = requests.get('https://zenodo.org/api/records/958140',headers)
record = json.loads(r.text)
print(record)
# Out:
# {'conceptrecid': '958139', 'created': '2017-09-23T07:11:00.162839+00:00', 'doi': '10.3897/zookeys.447.7766.figure1', 'files': [{'bucket': 'b645a5fb-e996-42a3-aaf5-a3f7ce75e853', 'checksum': 'md5:89a9f58721a73523c1ae855025b81ad4', 'key': 'oo_32747.jpg', 'links': {'self': 'https://zenodo.org/api/files/b645a5fb-e996-42a3-aaf5-a3f7ce75e853/oo_32747.jpg'}, 'size': 1085074, 'type': 'jpg'}], 'id': 958140, 'links': {'badge': 'https://zenodo.org/badge/doi/10.3897/zookeys.447.7766.figure1.svg', 'bucket': 'https://zenodo.org/api/files/b645a5fb-e996-42a3-aaf5-a3f7ce75e853', 'doi': 'https://doi.org/10.3897/zookeys.447.7766.figure1', 'html': 'https://zenodo.org/record/958140', 'latest': 'https://zenodo.org/api/records/958140', 'latest_html': 'https://zenodo.org/record/958140', 'self': 'https://zenodo.org/api/records/958140', 'thumb250': 'https://zenodo.org/api/iiif/v2/b645a5fb-e996-42a3-aaf5-a3f7ce75e853:24362cf0-7fe4-47d8-8a16-479f55cc98e9:oo_32747.jpg/full/250,/0/default.jpg', 'thumbs': {'10': 'https://zenodo.org/record/958140/thumb10', '100': 'https://zenodo.org/record/958140/thumb100', '1200': 'https://zenodo.org/record/958140/thumb1200', '250': 'https://zenodo.org/record/958140/thumb250', '50': 'https://zenodo.org/record/958140/thumb50', '750': 'https://zenodo.org/record/958140/thumb750'}}, 'metadata': {'access_right': 'open', 'access_right_category': 'success', 'communities': [{'id': 'biosyslit'}], 'creators': [{'affiliation': 'California Academy of Sciences, San Francisco, United States of America', 'name': 'Hita Garcia, Francisco'}, {'affiliation': 'Afribugs, Pretoria, South Africa', 'name': 'Hawkes, Peter'}, {'affiliation': 'Museum of Comparative Zoology, Cambridge, United States of America', 'name': 'Alpert, Gary D.'}], 'description': 'Figure 1 - Anterior part of cephalic dorsum in full-face view showing clypeus (within white ellipse) and calcar of strigil (white arrows indicate position of calcar). A Proceratium boltoni (CASENT0902424) (Will Ericson 2013) B Proceratium diplopyx (Malagasy member of Proceratium stictum clade) C Proceratium burundense (CASENT0902427) (Will Ericson 2013) D Proceratium sokoke (MCZ-ENT00520482).', 'doi': '10.3897/zookeys.447.7766.figure1', 'keywords': ['Animalia', 'Arthropoda', 'Insecta', 'Hymenoptera', 'Vespoidea', 'Formicidae', 'Proceratium', 'Proceratium boltoniAnimalia', 'Proceratium diplopyxAnimalia', 'Proceratium stictumAnimalia', 'Arabuko Sokoke Forest', 'Gorongosa National Park', 'Kenya', 'Mozambique', 'Nilo Forest', 'Proceratium arnoldi clade', 'Proceratium stictum clade', 'Proceratium toschii clade', 'Sali Forest', 'Tanzania', 'taxonomy'], 'license': {'id': 'CC-BY-4.0'}, 'publication_date': '2014-10-16', 'related_identifiers': [{'identifier': '10.3897/zookeys.447.7766', 'relation': 'isPartOf', 'scheme': 'doi'}], 'relations': {'version': [{'count': 1, 'index': 0, 'is_last': True, 'last_child': {'pid_type': 'recid', 'pid_value': '958140'}, 'parent': {'pid_type': 'recid', 'pid_value': '958139'}}]}, 'resource_type': {'subtype': 'figure', 'title': 'Figure', 'type': 'image'}, 'title': 'Figure 1 from: Hita Garcia F, Hawkes P, Alpert G (2014) Taxonomy of the ant genus Proceratium Roger (Hymenoptera, Formicidae) in the Afrotropical region with a revision of the P. arnoldi clade and description of four new species. ZooKeys 447: 47-86. https://doi.org/10.3897/zookeys.447.7766'}, 'owners': [1161], 'revision': 5, 'stats': {'downloads': 23.0, 'unique_downloads': 18.0, 'unique_views': 12.0, 'version_downloads': 23.0, 'version_unique_downloads': 18.0, 'version_unique_views': 12.0, 'version_views': 29.0, 'version_volume': 24956702.0, 'views': 29.0, 'volume': 24956702.0}, 'updated': '2019-10-09T13:14:28.807398+00:00'}

# %%
print(record['files'])
# Out:
# [{'bucket': 'b645a5fb-e996-42a3-aaf5-a3f7ce75e853', 'checksum': 'md5:89a9f58721a73523c1ae855025b81ad4', 'key': 'oo_32747.jpg', 'links': {'self': 'https://zenodo.org/api/files/b645a5fb-e996-42a3-aaf5-a3f7ce75e853/oo_32747.jpg'}, 'size': 1085074, 'type': 'jpg'}]

# %% [markdown]
# # Ejercicio

# %% [markdown]
# ### 1: Busca al menos dos repositorios digitales compatibles con OAI-PMH
#     - http://scientiamarina.revistas.csic.es/index.php/scientiamarina/oai
#     - http://digital.csic.es/dspace-oai/request

# %% [markdown]
# ### 2 y 3: Utiliza los verbos del protocolo para encontrar los recursos de un tema en concreto (puedes buscar en la descripción o en las palabras clave. Obtén un listado de los títulos, identificadores (DOI o cualquier otro) y la dirección del recurso.

# %%
import xml.etree.ElementTree as ET
import requests

# Hago la petición al servidor
# Algo pareceido al ejercicio (1)
oai = requests.get('http://scientiamarina.revistas.csic.es/index.php/scientiamarina/oai?verb=ListRecords&metadataPrefix=oai_dc')

# Creo el arbol xml
xmlTree = ET.fromstring(oai.text)

# Recorro el xmlTree:
# busco los elementos cuyo 'subject' sea 'Ebro River'
# y cuya 'description' contenga 'Ebro River'.
# Imprimo 'subject', 'description' (para confirmar que está todo bien),
# 'title' e 'identifier', para poder buscar el recurso.
records = xmlTree.findall('.//{http://www.openarchives.org/OAI/2.0/oai_dc/}dc')
for el in records:
    for subject in el.findall('.//{http://purl.org/dc/elements/1.1/}subject'):
        for description in el.findall('.//{http://purl.org/dc/elements/1.1/}description'):
            if 'Ebro River' in subject.text and 'Ebro River' in description.text: 
                print("Subject:",subject.text)
                print("Description:",description.text)
                print()
                title = el.findall('.//{http://purl.org/dc/elements/1.1/}title')[0].text
                print("Title:", title)
                identifier = el.findall('.//{http://purl.org/dc/elements/1.1/}identifier')[0].text
                print("Identifier:", identifier)
# Out:
# Subject: Ebro River; river plume; numerical modelling; hydrodynamics; dispersion
# Description: The spreading of the plume induced by the freshwater discharge from the Ebro River into northwestern Mediterranean coastal waters was modelled using two numerical codes. The coastal current field was obtained with a finite difference hydrodynamic model based on a steady-state version of the shallow-water equations, whereas the freshwater dispersion was calculated with a Lagrangian code that solves the 3D convection-diffusion equation and reproduces turbulent diffusion using a random-walk algorithm. The agreement obtained between numerical results, satellite observations and field measurements allows an analysis of the more relevant physical mechanisms and the corresponding tuning of the two models. The results show that local hydrodynamics near the river mouth, and consequently the spreading of the river plume, are highly dependent on the driving river discharge and wind field characteristics.
#
# Title: Modelling of the Ebro River plume. Validation with field observations
# Identifier: http://scientiamarina.revistas.csic.es/index.php/scientiamarina/article/view/492

# %% [markdown]
# ### 4: ¿Qué problemas has encontrado? ¿Has tenido que manejar más de un formato de metadatos? ¿Qué limitaciones tiene el protocolo OAI-PMH? ¿Cómo lo mejorarías?

# %% [markdown]
# Uno de los problemas principales que he encontrado es la falta de un estandard único para los metadatos.
#
# Esto implica que antes de cada búsqueda, sea necesaria una petición al servidor para saber cuáles formatos son disponibles. Probablemente eligiendo un sólo formato aceptado por la gran mayoria de los usuarios, sería más sencillo y más directo hacer búsqueda de metadatos con OAI-PMH.
#
# Por otro lado, las peticiones a *scientiamarina* resultan lentas y suelen fallar del todo, haciendo que la búsqueda sea lenta y poco fiable. Probablemente sea más una limitación del servidor que del protocolo OAI-PMH, peor ha hecho que este sencillo ejercicio resultase más costoso a nivel de tiempo de lo que había pensado.

# %% [markdown]
# ### 5: A través de los distintos métodos vistos (Uso de PID/DOI, OAI-PMH o APIs concretas de repositorios) intenta llegar al fichero de un dataset para mostrarlo (gráfica, imagen...)

# %%
# Busco en zenodo un elemento que contenga una imagen
# https://zenodo.org/record/3594113

oai = requests.get('https://zenodo.org/oai2d?verb=GetRecord&metadataPrefix=oai_dc&identifier=oai:zenodo.org:3594113')
xmlTree = ET.fromstring(oai.text)

iterator = xmlTree.iter()
for elem in iterator:
    print(elem.tag+": "+elem.text)
# Out:
# {http://www.openarchives.org/OAI/2.0/}OAI-PMH:
#
# {http://www.openarchives.org/OAI/2.0/}responseDate: 2019-12-27T22:24:51Z
# {http://www.openarchives.org/OAI/2.0/}request: https://zenodo.org/oai2d
# {http://www.openarchives.org/OAI/2.0/}GetRecord:
#
# {http://www.openarchives.org/OAI/2.0/}record:
#
# {http://www.openarchives.org/OAI/2.0/}header:
#
# {http://www.openarchives.org/OAI/2.0/}identifier: oai:zenodo.org:3594113
# {http://www.openarchives.org/OAI/2.0/}datestamp: 2019-12-27T20:51:22Z
# {http://www.openarchives.org/OAI/2.0/}metadata:
#
# {http://www.openarchives.org/OAI/2.0/oai_dc/}dc:
#
# {http://purl.org/dc/elements/1.1/}creator: Ghodsi M. Ziarani
# {http://purl.org/dc/elements/1.1/}creator: Fatemeh Mohajer
# {http://purl.org/dc/elements/1.1/}creator: , Razieh Moradi
# {http://purl.org/dc/elements/1.1/}creator: Parisa Mofatehnia.
# {http://purl.org/dc/elements/1.1/}date: 2019-12-04
# {http://purl.org/dc/elements/1.1/}description: As a matter of fact, nitrogen as a hetero atom among other atoms has had an important role in active biological compounds. Since heterocyclic molecules with nitrogen are highly demanded due to biological properties, 4-phenylurazole as a compound containing nitrogen might be important in the multicomponent reaction used in agrochemicals, and pharmaceuticals. Considering the case of fused derivatives “pyrazolourazoles” which are highly applicable because of their application for analgesic, antibacterial, anti-inflammatory and antidiabetic activities as HSP-72 induction inhibitors (I and III) and novel microtubule assembly inhibitors. It should be mentioned that spiro-pyrazole also has biological activities like cytotoxic, antimicrobial, anticonvulsant, antifungal, anticancer, anti-inflammatory, and cardiotonic activities.
# {http://purl.org/dc/elements/1.1/}identifier: https://zenodo.org/record/3594113
# {http://purl.org/dc/elements/1.1/}identifier: 10.2174/1570179416666190925162215
# {http://purl.org/dc/elements/1.1/}identifier: oai:zenodo.org:3594113
# {http://purl.org/dc/elements/1.1/}rights: info:eu-repo/semantics/openAccess
# {http://purl.org/dc/elements/1.1/}rights: http://creativecommons.org/licenses/by/4.0/legalcode
# {http://purl.org/dc/elements/1.1/}title: The Molecular Diversity Scope of Urazole in the Synthesis of Organic Compounds
# {http://purl.org/dc/elements/1.1/}type: info:eu-repo/semantics/article
# {http://purl.org/dc/elements/1.1/}type: publication-article

# %%
# Paso la dirección del archivo a la API de Zenodo,
# que me saca toda la información relativa al archivo

import json

headers = {'accept': 'application/json'}
r = requests.get('https://zenodo.org/api/records/3594113',headers)
record = json.loads(r.text)
print(record)
print()
# Out:
# {'conceptrecid': '3594112', 'created': '2019-12-27T20:51:20.887777+00:00', 'doi': '10.2174/1570179416666190925162215', 'files': [{'bucket': '96aae449-6381-4692-9634-9ab9297ad56b', 'checksum': 'md5:9cb6db45a98016b604e713a9004adf4d', 'key': '001.jpg', 'links': {'self': 'https://zenodo.org/api/files/96aae449-6381-4692-9634-9ab9297ad56b/001.jpg'}, 'size': 128037, 'type': 'jpg'}, {'bucket': '96aae449-6381-4692-9634-9ab9297ad56b', 'checksum': 'md5:482e177a9367c817e847b6c9fc470abe', 'key': 'Untitled.png', 'links': {'self': 'https://zenodo.org/api/files/96aae449-6381-4692-9634-9ab9297ad56b/Untitled.png'}, 'size': 266163, 'type': 'png'}], 'id': 3594113, 'links': {'badge': 'https://zenodo.org/badge/doi/10.2174/1570179416666190925162215.svg', 'bucket': 'https://zenodo.org/api/files/96aae449-6381-4692-9634-9ab9297ad56b', 'doi': 'https://doi.org/10.2174/1570179416666190925162215', 'html': 'https://zenodo.org/record/3594113', 'latest': 'https://zenodo.org/api/records/3594113', 'latest_html': 'https://zenodo.org/record/3594113', 'self': 'https://zenodo.org/api/records/3594113', 'thumb250': 'https://zenodo.org/api/iiif/v2/96aae449-6381-4692-9634-9ab9297ad56b:34802e7d-6e40-4fde-a0d8-c53502401ae9:001.jpg/full/250,/0/default.jpg', 'thumbs': {'10': 'https://zenodo.org/record/3594113/thumb10', '100': 'https://zenodo.org/record/3594113/thumb100', '1200': 'https://zenodo.org/record/3594113/thumb1200', '250': 'https://zenodo.org/record/3594113/thumb250', '50': 'https://zenodo.org/record/3594113/thumb50', '750': 'https://zenodo.org/record/3594113/thumb750'}}, 'metadata': {'access_right': 'open', 'access_right_category': 'success', 'creators': [{'affiliation': 'Alzahra university', 'name': 'Ghodsi M. Ziarani', 'orcid': '0000-0001-5177-7889'}, {'affiliation': 'Alzahra university', 'name': 'Fatemeh Mohajer', 'orcid': '0000-0003-0587-2230'}, {'affiliation': 'Alzahra university', 'name': ', Razieh Moradi'}, {'affiliation': 'Alzahra university', 'name': 'Parisa Mofatehnia.'}], 'description': '<p>As a matter of fact, nitrogen as a hetero atom among other atoms has had an important role in active biological compounds. Since heterocyclic molecules with nitrogen are highly demanded due to biological properties, 4-phenylurazole as a compound containing nitrogen might be important in the multicomponent reaction used in agrochemicals, and pharmaceuticals. Considering the case of fused derivatives &ldquo;pyrazolourazoles&rdquo; which are highly applicable because of their application for analgesic, antibacterial, anti-inflammatory and antidiabetic activities as HSP-72 induction inhibitors (I and III) and novel microtubule assembly inhibitors. It should be mentioned that spiro-pyrazole also has biological activities like cytotoxic, antimicrobial, anticonvulsant, antifungal, anticancer, anti-inflammatory, and cardiotonic activities.</p>', 'doi': '10.2174/1570179416666190925162215', 'license': {'id': 'CC-BY-4.0'}, 'publication_date': '2019-12-04', 'relations': {'version': [{'count': 1, 'index': 0, 'is_last': True, 'last_child': {'pid_type': 'recid', 'pid_value': '3594113'}, 'parent': {'pid_type': 'recid', 'pid_value': '3594112'}}]}, 'resource_type': {'subtype': 'article', 'title': 'Journal article', 'type': 'publication'}, 'title': 'The Molecular Diversity Scope of Urazole in the Synthesis of Organic Compounds'}, 'owners': [72104], 'revision': 1, 'stats': {'downloads': 0.0, 'unique_downloads': 0.0, 'unique_views': 0.0, 'version_downloads': 0.0, 'version_unique_downloads': 0.0, 'version_unique_views': 0.0, 'version_views': 0.0, 'version_volume': 0.0, 'views': 0.0, 'volume': 0.0}, 'updated': '2019-12-27T20:51:22.943064+00:00'}

# %%
# De toda la información, me quedo con la relacionada a las imagenes
# en mi caso, jpg
for element in record['files']:
    if "jpg" in element.values():
        print(element)
# Out:
# {'bucket': '96aae449-6381-4692-9634-9ab9297ad56b', 'checksum': 'md5:9cb6db45a98016b604e713a9004adf4d', 'key': '001.jpg', 'links': {'self': 'https://zenodo.org/api/files/96aae449-6381-4692-9634-9ab9297ad56b/001.jpg'}, 'size': 128037, 'type': 'jpg'}

# %%
# Uso el link para pintar la imagen
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://zenodo.org/api/files/96aae449-6381-4692-9634-9ab9297ad56b/001.jpg")
# Out:
# <img src="https://zenodo.org/api/files/96aae449-6381-4692-9634-9ab9297ad56b/001.jpg"/>
